# %%
import pandas as pd
import numpy as np
import datetime
import gc

DATA_PATH = "C:\\Users\\juliahu\\Documents\\Python Scripts"

# %%
tm_format = '%Y-%m-%d %H:%M:%S'
current_month = datetime.datetime.now().month
# Load the original train data
train_df = pd.read_csv(DATA_PATH + '\\sensors.csv',index_col='Timestamp')
# Load labels
labels_df = pd.read_csv(DATA_PATH + '\\labels.csv', header=None)
labels_df.columns = ['start', 'end']
# Build inference data with future timestamps

# %%
len(train_df)
# Out:
# 86400

# %%
train_df.head()
# Out:
#                       Sensor0   Sensor1   Sensor2   Sensor3   Sensor4  \
# Timestamp
# 2019-01-01 00:00:00 -0.828743 -0.068548  0.151633 -0.194587  0.862565
# 2019-01-01 00:05:00  0.019142 -0.946242  0.580651 -0.155384  0.116038
# 2019-01-01 00:10:00 -0.036186  0.206872  0.343356  0.083626 -0.342867
# 2019-01-01 00:15:00 -0.550611 -0.301188  0.148512  0.051228 -0.385147
# 2019-01-01 00:20:00 -0.606425 -0.331560 -0.093932  0.784581  0.256889
#
#                       Sensor5   Sensor6   Sensor7   Sensor8   Sensor9  ...  \
# Timestamp                                                              ...
# 2019-01-01 00:00:00  0.380223  6.852690  6.299292  7.219419  7.004522  ...
# 2019-01-01 00:05:00 -0.185083  6.720679  7.688384  6.779484  6.979925  ...
# 2019-01-01 00:10:00 -0.461456  7.581135  7.061488  6.230064  6.859606  ...
# 2019-01-01 00:15:00 -0.008690  7.486352  7.303732  6.881112  6.877079  ...
# 2019-01-01 00:20:00 -1.209056  7.010256  6.758775  7.089719  6.988612  ...
#
# ...

# %%
train_df.tail()
# Out:
#                       Sensor0   Sensor1   Sensor2   Sensor3   Sensor4  \
# Timestamp
# 2019-10-27 23:35:00  0.572524  0.831853  0.012117 -0.170698 -0.468361
# 2019-10-27 23:40:00  0.100300  0.808269 -0.956786  0.374711 -1.346233
# 2019-10-27 23:45:00 -0.315199  0.077039  0.043951 -0.605731  1.199912
# 2019-10-27 23:50:00 -0.384450 -0.618395  0.436698  1.208248  0.861525
# 2019-10-27 23:55:00  0.151450  1.013531 -0.198544  0.400527 -0.081966
#
#                       Sensor5   Sensor6   Sensor7   Sensor8   Sensor9  ...  \
# Timestamp                                                              ...
# 2019-10-27 23:35:00 -0.938305  7.014236  6.712674  7.047559  7.205919  ...
# 2019-10-27 23:40:00 -0.949926  7.621383  6.781719  6.918772  7.916911  ...
# 2019-10-27 23:45:00  0.247149  7.405565  7.736269  6.358986  6.946860  ...
# 2019-10-27 23:50:00 -0.175508  6.440132  7.107447  7.078380  6.518570  ...
# 2019-10-27 23:55:00 -0.872504  7.285478  6.792989  6.838044  7.271361  ...
#
# ...

# %%
train_df_a = train_df.iloc[:21600,:]
print(train_df_a)
# Out:
#                       Sensor0   Sensor1   Sensor2   Sensor3   Sensor4  \
# Timestamp
# 2019-01-01 00:00:00 -0.828743 -0.068548  0.151633 -0.194587  0.862565
# 2019-01-01 00:05:00  0.019142 -0.946242  0.580651 -0.155384  0.116038
# 2019-01-01 00:10:00 -0.036186  0.206872  0.343356  0.083626 -0.342867
# 2019-01-01 00:15:00 -0.550611 -0.301188  0.148512  0.051228 -0.385147
# 2019-01-01 00:20:00 -0.606425 -0.331560 -0.093932  0.784581  0.256889
# ...                       ...       ...       ...       ...       ...
# 2019-03-16 23:35:00 -0.158473  0.688270  0.669230  0.116056 -0.333806
# 2019-03-16 23:40:00 -0.323958  0.562898 -0.499889 -0.233689 -0.573252
# 2019-03-16 23:45:00 -0.029829 -0.049611  0.806907 -0.543105  0.555424
# 2019-03-16 23:50:00  0.762678 -0.831355 -0.310567 -0.322093  0.110675
# 2019-03-16 23:55:00  0.108429 -0.134455 -0.181806 -0.500747 -1.034744
#
#                       Sensor5   Sensor6   Sensor7   Sensor8   Sensor9  ...  \
# ...

# %%
train_df_a.to_dict('list')
# Out:
# {'Sensor0': [-0.8287425034061038,
#   0.0191416354117442,
#   -0.036186015483254716,
#   -0.5506105471665163,
#   -0.6064253258205092,
#   0.15627219934924025,
#   -0.3048463588929381,
#   -0.5842769344745836,
#   1.3661549440425935,
#   0.09828566005890496,
#   -0.2191661113206992,
#   -0.3474665055463043,
#   0.3813707773379289,
#   0.08552856700087992,
#   -0.4086074069047322,
#   -0.5953155707441693,
#   -0.21755153361342566,
#   -0.028769316487846468,
#   0.2808395981017792,
#   0.4769284082955051,
#   0.5132728097505905,
#   0.008261520847391336,
#   0.7143699793078424,
#   0.3654286143856148,
#   0.15357831373500014,
#   -1.2008315225962678,
#   0.14110315734253492,
#   0.1555901660650209,
#   0.32849931094003026,
#   -0.3634335598003018,
#   -0.9356007568552568,
#   0.09817881750176448,
#   -0.06392451029879434,
#   0.11491280872680427,
#   -0.16307558230495695,
#   -0.7493146555848774,
#   0.5672490406588888,
#   -0.4892057859959619,
#   -0.7096893224410619,
# ...

# %%
import json
  
train_df_dic = train_df_a.to_dict('list')
  
with open('Demo Pump Asset 1.txt', 'w') as convert_file:
     convert_file.write(json.dumps(train_df_dic))

# %%
train_df_b = train_df.iloc[21600:43200,:]
print(train_df_b)
# Out:
#                       Sensor0   Sensor1   Sensor2   Sensor3   Sensor4  \
# Timestamp
# 2019-03-17 00:00:00 -0.422072 -0.755718  0.387833 -0.693543 -0.259921
# 2019-03-17 00:05:00  0.366395  0.012413  0.091427  0.270414  0.126691
# 2019-03-17 00:10:00  0.285086 -0.738634 -0.717354  0.465838 -0.375168
# 2019-03-17 00:15:00  0.113113  0.238695 -0.245853 -1.348768 -0.883018
# 2019-03-17 00:20:00 -0.720567  0.203917 -0.264128  0.074722  0.012415
# ...                       ...       ...       ...       ...       ...
# 2019-05-30 23:35:00  0.257483 -0.900442  0.159392 -0.388810  0.134562
# 2019-05-30 23:40:00 -0.156579 -1.273579 -0.210647 -0.688799 -0.010600
# 2019-05-30 23:45:00 -0.638224 -0.193906 -0.335045  0.945868 -0.243517
# 2019-05-30 23:50:00 -0.009779 -1.152736 -0.019203  0.449876 -0.041280
# 2019-05-30 23:55:00 -0.615487 -0.161721  0.461361 -0.154612  0.087326
#
#                       Sensor5    Sensor6    Sensor7    Sensor8    Sensor9  \
# Timestamp
# ...

# %%
train_df_b.to_dict('list')
# Out:
# {'Sensor0': [-0.4220718844291893,
#   0.3663948758301828,
#   0.2850863644772102,
#   0.11311344580509225,
#   -0.7205673070688853,
#   0.3106946086838326,
#   -0.2516429073454152,
#   0.05589008785369457,
#   -0.3879842068578756,
#   0.016470544139602073,
#   -0.21605068741506372,
#   0.3204263619869324,
#   -0.28674851300289106,
#   0.17225690151259904,
#   -0.7362079305160132,
#   -1.154281709583138,
#   0.15585153563072254,
#   0.3815374610846175,
#   -0.1347770167160444,
#   0.3739649186575677,
#   -0.3957558636579239,
#   -0.6618103768545481,
#   -0.0872679935986938,
#   0.05738191743159993,
#   -0.3494440413169092,
#   -0.5455832721027267,
#   -0.7394842914694844,
#   -0.025447696657436892,
#   0.07878250686107201,
#   0.7442350139786386,
#   0.3032757592924485,
#   0.04613531176637138,
#   -0.24958150738417906,
#   0.2458975123972757,
#   -0.2150364969505704,
#   0.09759226336818208,
#   -0.2054992378643175,
#   -0.14523353733812167,
#   -0.3422307085515309,
# ...

# %%
import json
  
train_df_dic2 = train_df_b.to_dict('list')
  
with open('Demo Pump Asset 2.txt', 'w') as convert_file:
     convert_file.write(json.dumps(train_df_dic2))

# %%
####Read asset data back, to have a final check on length

# %%
import json
with open('Demo Pump Asset 2.txt') as json_file:
    a = json.load(json_file)

# %%
len(a['Sensor29'])
# Out:
# 21600

# %%
import pandas as pd
import datetime
# Extract labels for the same month as current month
def find_current_labels(labels_df):
    mask = []
    for row in labels_df.iterrows():
        start_month = datetime.datetime.strptime(row[1]['start'], tm_format).month
        end_month = datetime.datetime.strptime(row[1]['end'], tm_format).month
        if start_month >= current_month >= end_month:
            mask.append(True)
        else:
            mask.append(False)
    return labels_df.loc[mask,:]

# %%
current_labels_df = find_current_labels(labels_df)

# %%
print(current_labels_df)
# Out:
#                   start                  end
# 18  2019-07-09 00:00:00  2019-07-10 00:00:00
# 19  2019-07-19 00:00:00  2019-07-20 00:00:00
# 20  2019-07-29 00:00:00  2019-07-30 00:00:00

# %%
# generate abnormal data
start_anom_df = train_df.loc[current_labels_df.iloc[0,0]:,:]

# %%
print(start_anom_df)
# Out:
#                       Sensor0   Sensor1   Sensor2   Sensor3   Sensor4  \
# Timestamp
# 2019-07-09 00:00:00  0.026400 -0.376180 -0.025937  0.152773  0.016193
# 2019-07-09 00:05:00 -0.114691 -0.651170 -0.514037 -0.251946  0.205765
# 2019-07-09 00:10:00  0.078527  0.035439  0.423317 -0.325731 -0.172325
# 2019-07-09 00:15:00  0.539519  0.027748  0.207297  0.479220  0.719307
# 2019-07-09 00:20:00 -0.095191  0.522484 -0.444699 -0.064749  0.560722
# ...                       ...       ...       ...       ...       ...
# 2019-10-27 23:35:00  0.572524  0.831853  0.012117 -0.170698 -0.468361
# 2019-10-27 23:40:00  0.100300  0.808269 -0.956786  0.374711 -1.346233
# 2019-10-27 23:45:00 -0.315199  0.077039  0.043951 -0.605731  1.199912
# 2019-10-27 23:50:00 -0.384450 -0.618395  0.436698  1.208248  0.861525
# 2019-10-27 23:55:00  0.151450  1.013531 -0.198544  0.400527 -0.081966
#
#                       Sensor5    Sensor6    Sensor7    Sensor8    Sensor9  \
# Timestamp
# ...

# %%
train_df_c = train_df.iloc[43200:64800, :]
print(train_df_c)
# Out:
#                       Sensor0   Sensor1   Sensor2   Sensor3   Sensor4  \
# Timestamp
# 2019-05-31 00:00:00 -0.133063 -0.079898  0.341681 -0.482610 -0.790458
# 2019-05-31 00:05:00 -0.693999  0.368731  0.723911 -0.634518  0.381756
# 2019-05-31 00:10:00 -0.063410  0.065549  0.395773 -0.422137  0.698867
# 2019-05-31 00:15:00  0.177595 -0.492687 -0.537681 -0.402737 -0.161266
# 2019-05-31 00:20:00  0.803253  0.149459 -0.663246  0.583691 -0.593164
# ...                       ...       ...       ...       ...       ...
# 2019-08-13 23:35:00  0.300784  0.466076 -0.046171 -0.057294  0.046156
# 2019-08-13 23:40:00 -0.079710  0.629516 -0.046415  0.712232  0.773937
# 2019-08-13 23:45:00  0.394930  0.466307  0.675718 -0.967070 -0.507632
# 2019-08-13 23:50:00  0.203006 -0.376340  0.245845 -0.645988  0.231197
# 2019-08-13 23:55:00 -0.052071  0.060337  0.329738  0.335612  0.311406
#
#                       Sensor5   Sensor6   Sensor7   Sensor8   Sensor9  ...  \
# ...

# %%
train_abnorm_df = start_anom_df.iloc[:10000,:].append(train_df_c[:11600], ignore_index=True)

# %%
len(train_abnorm_df)
# Out:
# 21600

# %%
train_abnorm_df
# Out:
#         Sensor0   Sensor1   Sensor2   Sensor3   Sensor4   Sensor5    Sensor6  \
# 0      0.026400 -0.376180 -0.025937  0.152773  0.016193 -0.436031   9.800109
# 1     -0.114691 -0.651170 -0.514037 -0.251946  0.205765 -0.040189  10.225059
# 2      0.078527  0.035439  0.423317 -0.325731 -0.172325 -0.812912  11.272513
# 3      0.539519  0.027748  0.207297  0.479220  0.719307  0.235868  11.567774
# 4     -0.095191  0.522484 -0.444699 -0.064749  0.560722 -0.443022  10.188012
# ...         ...       ...       ...       ...       ...       ...        ...
# 21595 -0.944221  0.267168 -0.071801 -0.592477  0.086241 -0.630421   6.994935
# 21596  0.122612  0.362677  0.519673  0.093162 -0.193219 -0.252132   7.127848
# 21597 -0.939941  0.479018 -1.045553 -0.302750  0.001691 -0.039869   7.459657
# 21598  1.273038  0.282843 -0.160521  0.516073 -0.239904 -0.746946   6.668000
# 21599  0.071064 -0.546915 -0.302102  0.855822  0.076456 -0.590998   7.610787
#
# ...

# %%
import json
traint_abnorm_dic = train_abnorm_df.to_dict('list')  
with open('Demo Pump Asset 3.txt', 'w') as convert_file:
     convert_file.write(json.dumps(traint_abnorm_dic))

# %%
import json
with open('Demo Pump Asset 3.txt') as json_file:
    a = json.load(json_file)

# %%
len(a['Sensor5'])
# Out:
# 21600
